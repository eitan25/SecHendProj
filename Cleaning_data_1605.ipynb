# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('./data/cars_data1605.csv', index_col=0)
data
# Out:
#           ad_num      company          model     price  engine  year  hand  \
# 1     65146899.0  ג'יפ / Jeep   גרנד צ'ירוקי  140000.0  3604.0  2017     2
# 2     73811682.0  ג'יפ / Jeep     רנגלר ארוך  268000.0  1995.0  2021     2
# 3     77276021.0     מיצובישי  אאוטלנדר PHEV  149000.0  2360.0  2020     2
# 4     55670284.0       שברולט   טרייל בלייזר  145000.0  1341.0  2022     1
# 5     93516523.0        וולוו           XC60  250000.0  1969.0  2022     2
# ...          ...          ...            ...       ...     ...   ...   ...
# 3384  61230592.0        מאזדה              3   15000.0  1598.0  2009     3
# 3385  96450445.0       טויוטה  אוריס הייבריד   62000.0  1798.0  2014     3
# 3386  87660871.0         פיאט          דובלו   58000.0  1598.0  2017     1
# 3387  69065361.0  ג'יפ / Jeep         קומפאס  230000.0  1332.0  2022     1
# 3388  94410775.0        מרצדס            GLB  245000.0  1332.0  2020     1
#
# ...

# %%
data[data.price0705 == -1]
# check for previous scrap
# Out:
#           ad_num      company          model     price  engine  year  hand  \
# 2     73811682.0  ג'יפ / Jeep     רנגלר ארוך  268000.0  1995.0  2021     2
# 3     77276021.0     מיצובישי  אאוטלנדר PHEV  149000.0  2360.0  2020     2
# 8     68824067.0     מיצובישי       אאוטלנדר  101000.0  1998.0  2016     1
# 11    71076975.0        הונדה           HR-V   83000.0  1498.0  2018     2
# 13    61237674.0       סובארו         פורסטר   90000.0  1995.0  2016     2
# ...          ...          ...            ...       ...     ...   ...   ...
# 3370  76954626.0    פולקסווגן           ג'טה   28000.0  1390.0  2014     2
# 3371  71375505.0       יונדאי          טוסון  119000.0  1999.0  2020     2
# 3375  85713605.0        סקודה        אוקטביה   24000.0  1197.0  2011     3
# 3379  56623393.0         סיאט           לאון   75000.0  1395.0  2017     2
# 3381  78781396.0        ניסאן          קשקאי  130000.0  1332.0  2020     1
#
# ...

# %%
data[data.price1605 == -1]
# check for current scrap
# Out:
#           ad_num      company          model     price  engine  year  hand  \
# 2     73811682.0  ג'יפ / Jeep     רנגלר ארוך  268000.0  1995.0  2021     2
# 3     77276021.0     מיצובישי  אאוטלנדר PHEV  149000.0  2360.0  2020     2
# 6     91102050.0          קיה        ספורטז'   95000.0  1999.0  2017     1
# 8     68824067.0     מיצובישי       אאוטלנדר  101000.0  1998.0  2016     1
# 9     78325029.0       איסוזו      טרופר קצר   17000.0  3494.0  1999     6
# ...          ...          ...            ...       ...     ...   ...   ...
# 3371  71375505.0       יונדאי          טוסון  119000.0  1999.0  2020     2
# 3375  85713605.0        סקודה        אוקטביה   24000.0  1197.0  2011     3
# 3379  56623393.0         סיאט           לאון   75000.0  1395.0  2017     2
# 3381  78781396.0        ניסאן          קשקאי  130000.0  1332.0  2020     1
# 3382  55376040.0        מאזדה              3   88000.0  1998.0  2019     3
#
# ...

# %% [markdown]
# # More cars sold
#
# we can see that in 9 days another ~400 cars sold.
#
# # We need to visualize the price in order to find out new Outliers
#
# like we had in the second scrap when someone decided to give an astronomical.

# %%
car16_plot = data.groupby(['ad_num']).mean()[['price1605']]
car07_plot = data.groupby(['ad_num']).mean()[['price0705']]
car_plot = data.groupby(['ad_num']).mean()[['price']]

car16_plot.plot()
car07_plot.plot()
car_plot.plot()
# Out:
# <AxesSubplot:xlabel='ad_num'>

# %%
data[data.price1605 == data.price1605.max()]
# Out:
#           ad_num company model     price  engine  year  hand      km  \
# 2000  73411362.0   מרצדס   CLS  360000.0  1991.0  2020     1  130000
#
#       eng_kind     test  ...  color  gearbox  trader  area  sub_area  \
# 2000         7  08/2023  ...      2      0.0       0   100   ירושלים
#
#       price_list price0705  enc_company  enc_model  price1605
# 2000    537000.0  360000.0            7        197   550000.0
#
# [1 rows x 22 columns]

# %% [markdown]
# We can see that the most expensive car is a luxury car
#
# its price list is 537k, the first and second scrap showed a price much lower of 360k
#
# therefor we can assume that the change of the price is an outcome of the price list discovery by the saler.

# %% [markdown]
# # Add new column sold
#
# for all sold cars.

# %%
# add nex col sold
data['sold'] = None
data
# Out:
#           ad_num      company          model     price  engine  year  hand  \
# 1     65146899.0  ג'יפ / Jeep   גרנד צ'ירוקי  140000.0  3604.0  2017     2
# 2     73811682.0  ג'יפ / Jeep     רנגלר ארוך  268000.0  1995.0  2021     2
# 3     77276021.0     מיצובישי  אאוטלנדר PHEV  149000.0  2360.0  2020     2
# 4     55670284.0       שברולט   טרייל בלייזר  145000.0  1341.0  2022     1
# 5     93516523.0        וולוו           XC60  250000.0  1969.0  2022     2
# ...          ...          ...            ...       ...     ...   ...   ...
# 3384  61230592.0        מאזדה              3   15000.0  1598.0  2009     3
# 3385  96450445.0       טויוטה  אוריס הייבריד   62000.0  1798.0  2014     3
# 3386  87660871.0         פיאט          דובלו   58000.0  1598.0  2017     1
# 3387  69065361.0  ג'יפ / Jeep         קומפאס  230000.0  1332.0  2022     1
# 3388  94410775.0        מרצדס            GLB  245000.0  1332.0  2020     1
#
#           km  eng_kind     test  ...  gearbox  trader  area  \
# ...

# %%
for index,row in data.iterrows():
    if row.price1605 == -1:
        data.at[index,'sold'] = 1
    else:
        data.at[index,'sold'] = 0
data
# Out:
#           ad_num      company          model     price  engine  year  hand  \
# 1     65146899.0  ג'יפ / Jeep   גרנד צ'ירוקי  140000.0  3604.0  2017     2
# 2     73811682.0  ג'יפ / Jeep     רנגלר ארוך  268000.0  1995.0  2021     2
# 3     77276021.0     מיצובישי  אאוטלנדר PHEV  149000.0  2360.0  2020     2
# 4     55670284.0       שברולט   טרייל בלייזר  145000.0  1341.0  2022     1
# 5     93516523.0        וולוו           XC60  250000.0  1969.0  2022     2
# ...          ...          ...            ...       ...     ...   ...   ...
# 3384  61230592.0        מאזדה              3   15000.0  1598.0  2009     3
# 3385  96450445.0       טויוטה  אוריס הייבריד   62000.0  1798.0  2014     3
# 3386  87660871.0         פיאט          דובלו   58000.0  1598.0  2017     1
# 3387  69065361.0  ג'יפ / Jeep         קומפאס  230000.0  1332.0  2022     1
# 3388  94410775.0        מרצדס            GLB  245000.0  1332.0  2020     1
#
#           km  eng_kind     test  ...  gearbox  trader  area  \
# ...

# %%
data.to_csv('./data/clean_cars1605.csv')

# %% [markdown]
# # Data saved and ready to work
